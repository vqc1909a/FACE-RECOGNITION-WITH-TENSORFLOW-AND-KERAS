# %%
import cv2
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
from PIL import Image

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LENOVO\\OneDrive\\Python\\Proyectos\\Face Recognition with Tensorflow and Keras'

# %% [markdown]
# ### Cargar modelo VGG16

# %%
model_vgg16 = load_model('./Models/model_vgg16.h5')

# %%
model_vgg16.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# ...

# %% [markdown]
# ### Cargar modelo vgg19

# %%
model_vgg19 = load_model('./Models/model_vgg19.h5')

# %%
model_vgg19.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# ...

# %% [markdown]
# ### Prueba vgg16

# %%
imagen_prueba = cv2.imread('brayan_prueba.jpg');
imagen_prueba = tf.keras.applications.vgg16.preprocess_input(imagen_prueba)
imagen_prueba = cv2.resize(imagen_prueba, (224, 224))

plt.imshow(imagen_prueba)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
imagen_prediction = model_vgg16.predict(x=np.array([imagen_prueba]), verbose=0);
imagen_prediction
# Out:
# array([[0.01162198, 0.97848755, 0.00989039]], dtype=float32)

# %% [markdown]
# ### Prueba vgg19

# %%
imagen_prueba2 = cv2.imread('brayan_prueba.jpg');
imagen_prueba2 = tf.keras.applications.vgg19.preprocess_input(imagen_prueba2)
imagen_prueba2 = cv2.resize(imagen_prueba, (224, 224))
plt.imshow(imagen_prueba2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
imagen_prediction2 = model_vgg16.predict(x=np.array([imagen_prueba2]), verbose=0);
imagen_prediction2
# Out:
# array([[0.03435859, 0.82896453, 0.09321443, 0.04346248]], dtype=float32)

# %%
faceClassif = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture("original_ronald1.mp4")

locals()["persona" + str(0)] = ''
locals()["persona" + str(1)] = ''
contador = 0;
result = ''
while (cap.isOpened()):
   ret, frame = cap.read()
   frame = cv2.resize(frame, (1366, 768))    
   
   roi_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)   
   gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
   scaleFactor = 1.25
   minNeighbors = 5

   faces = faceClassif.detectMultiScale(gray, scaleFactor, minNeighbors)
   for (i, (x, y, w, h)) in enumerate(faces):
    
       #Construir mi marco de interes
       original = roi_frame[y:y+h,x:x+w]
       roi =  roi_frame[y-140:y+h+70,x-70:x+w+70]
       #recognize for each 20 frames /deep learning 
         
       try:
           if w >= 224 and h >= 224:
               #Contador con variables locals
               #if contador % 40 == 0 or contador == 0:
               #    imagen_roi = tf.keras.applications.vgg16.preprocess_input(roi)
               #    imagen_roi = cv2.resize(imagen_roi, (224, 224))
               #    imagen_predict = np.array([imagen_roi]);
               #    prediction = model_vgg16.predict(x=imagen_predict, verbose=0);
               #    print(prediction)
               #    persona = np.argmax(prediction, axis=-1)[0];
               #    probabilidad_persona = prediction[0][persona]
               #    print(probabilidad_persona)
               #    if persona == 0:
               #       locals()["persona" + str(i)] = "Cesar"
               #    elif persona == 1:
               #       locals()["persona" + str(i)] = "Brayan" 
               #    elif persona == 2:
               #       locals()["persona" + str(i)] = "Ronald" 
               #    elif persona == 3:
               #       locals()["persona" + str(i)] = "Eduardo" 

               #Contador sin variables locals
               #if contador % 40 == 0:
                imagen_roi = tf.keras.applications.vgg16.preprocess_input(roi)
                imagen_roi = cv2.resize(imagen_roi, (224, 224))
                imagen_predict = np.array([imagen_roi]);
                prediction = model_vgg16.predict(x=imagen_predict, verbose=0);
                print(prediction)
                persona = np.argmax(prediction, axis=-1)[0];                   
                if persona == 0:
                  result = "Cesar"
                elif persona == 1:
                  result = "Brayan" 
                elif persona == 2:
                  result = "Ronald" 
                elif persona == 3:
                  result = "Eduardo" 

               #Impresion con variables locals
               #cv2.putText(frame, f'{locals()["persona" + str(i)]}', (x, y-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 239), 5, cv2.FILLED)
               #cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 255, 255), 2) 

               #Impresion sin variables locals         
                cv2.putText(frame, f'{result}', (x, y-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 239), 5, cv2.FILLED)
                cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 255, 255), 2)
       except Exception as e:
           print('')     
      
            
   
   cv2.putText(frame, "Salir de la aplicacion: Tecla s", (825, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3, cv2.FILLED)
   cv2.imshow('frame', frame)
   
   if cv2.waitKey(1) & 0xFF == ord('s'):
      break
   contador+=1
cap.release()
cv2.destroyAllWindows()
# Out:
# [[0.01694204 0.01811512 0.9649428 ]]
# [[0.01804754 0.03610101 0.94585145]]
# [[0.00790851 0.01093726 0.98115426]]
# [[0.01147743 0.01350008 0.9750225 ]]
# [[0.01110468 0.01445636 0.97443897]]
# [[0.0094071  0.01643179 0.974161  ]]
# [[0.00796727 0.01074735 0.98128533]]
# [[0.01169198 0.02214776 0.96616024]]
# [[0.01130584 0.01923807 0.96945614]]
# [[0.01477082 0.02051328 0.9647159 ]]
#
# [[0.00843295 0.01026886 0.9812982 ]]
#
#
#
#
# [[0.01089346 0.01408663 0.9750199 ]]
# [[0.01374859 0.02271352 0.9635379 ]]
# [[0.00944795 0.01929953 0.9712525 ]]

# %%
[[0.9364842  0.06351581]]
0.9364842
[[0.9178846  0.08211537]]
0.9178846
[[0.8762224  0.12377761]]
0.8762224
[[0.9085468  0.09145319]]
0.9085468
[[0.5634512  0.43654886]]
0.5634512
[[0.37814915 0.6218509 ]]
0.6218509
[[0.60509664 0.39490333]]
0.60509664





[[0.24816479 0.7518352 ]]
0.7518352
[[0.5565538  0.44344622]]
0.5565538

# %%
plt.imshow(roi)

# %%
foto.shape
# Out:
# (519, 449, 3)

# %%
imagen_re = Image.fromarray(foto)
imagen_redi = imagen_re.resize((224, 224), Image.ANTIALIAS)

# %%
plt.show(imagen_redi)

# %%
imagen_redi = np.array(imagen_redi)
imagen_redi.shape
# Out:
# (224, 224, 3)

# %%
        imagen_roi = cv2.resize(imagen_roi, (224, 224), interpolation=cv2.INTER_AREA)
        imagen_predict = np.array([imagen_roi]);
        
        prediction = model_vgg16.predict(x=imagen_predict, verbose=0);
        persona = np.argmax(prediction, axis=-1)[0];
        
        if persona == 0:
           resultado = "Cesar"
        elif persona == 1:
           resultado = "Yoshira"
      
        cv2.putText(frame, f'{resultado}', (
        x, y-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 239), 5, cv2.FILLED)

        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 255, 255), 2)
